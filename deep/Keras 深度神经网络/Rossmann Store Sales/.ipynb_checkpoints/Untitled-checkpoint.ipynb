# %%
import pandas as pd
df = pd.read_csv("train.csv")
# Out:
# C:\Users\77429\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print("Shape of the Dataset:",df.shape)
#the head method displays the first 5 rows of the data
df.head(5)
# Out:
# Shape of the Dataset: (1017209, 9)
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store = pd.read_csv("store.csv")
print("Shape of the Dataset:",store.shape)
#Display the first 5 rows of data using the head method of pandas dataframe
store.head()
# Out:
# Shape of the Dataset: (1115, 10)
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
df_new = df.merge(store,on=["Store"], how="inner")
print(df_new.shape)
# Out:
# (1017209, 18)

# %%
df_new.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      1          4  2015-07-30   5020        546     1      1            0
# 2      1          3  2015-07-29   4782        523     1      1            0
# 3      1          2  2015-07-28   5011        560     1      1            0
# 4      1          1  2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# 2                        9.0                    2008.0       0
# 3                        9.0                    2008.0       0
# 4                        9.0                    2008.0       0
#
#    Promo2SinceWeek  Promo2SinceYear PromoInterval
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3              NaN              NaN           NaN
# 4              NaN              NaN           NaN

# %%
print("Distinct number of Stores :", len(df_new["Store"].unique()))
print("Distinct number of Days :", len(df_new["Date"].unique()))
print("Average daily sales of all stores :",round(df_new["Sales"].mean(),2))
# Out:
# Distinct number of Stores : 1115
# Distinct number of Days : 942
# Average daily sales of all stores : 5773.82

# %%
df_new.dtypes
# Out:
# Store                          int64
# DayOfWeek                      int64
# Date                          object
# Sales                          int64
# Customers                      int64
# Open                           int64
# Promo                          int64
# StateHoliday                  object
# SchoolHoliday                  int64
# StoreType                     object
# Assortment                    object
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                 object
# dtype: object

# %%
df_new["DayOfWeek"].value_counts()
# Out:
# 5    145845
# 4    145845
# 3    145665
# 2    145664
# 7    144730
# 6    144730
# 1    144730
# Name: DayOfWeek, dtype: int64

# %%
#We can extract all date properties from a datetime datatype
import numpy as np
df_new['Date']=pd.to_datetime(df_new['Date'], infer_datetime_format=True)
df_new["Month"]=df_new["Date"].dt.month
df_new['Quarter']=df_new['Date'].dt.quarter
df_new['Year']=df_new['Date'].dt.year
df_new['Day']=df_new['Date'].dt.day
df_new['Week']=df_new['Date'].dt.week

df_new['Season']=np.where(df_new['Month'].isin([3,4,5]),"Spring",
                         np.where(df_new['Month'].isin([6,7,8]),"Summer",
                                 np.where(df_new['Month'].isin([9,10,11]),"Fall",
                                        np.where(df_new["Month"].isin([12,1,2]),"Winter","None"))))
#Using the head command to view (only) the data and the newly engineered features
print(df_new[["Date","Year","Month","Day","Week","Quarter","Season"]].head())
# Out:
# <ipython-input-11-160e16e0e9c3>:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df_new['Week']=df_new['Date'].dt.week
#         Date  Year  Month  Day  Week  Quarter  Season
# 0 2015-07-31  2015      7   31    31        3  Summer
# 1 2015-07-30  2015      7   30    31        3  Summer
# 2 2015-07-29  2015      7   29    31        3  Summer
# 3 2015-07-28  2015      7   28    31        3  Summer
# 4 2015-07-27  2015      7   27    31        3  Summer

# %%
#Import matplotlib,python most popular data visualizing library
import matplotlib.pyplot as plt
# %matplotlib inline
#Create a histogram to study the Daily Sales for the stores
plt.figure(figsize=(15,8))
plt.hist(df_new["Sales"])
plt.title("Histogram for Store Sales")
plt.xlabel("Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Use the histogram function provided by the Pandas object
#The function returns a cross-tab histogram plot for all numeric columns in the data
df_new.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Store'}>,
#         <AxesSubplot:title={'center':'DayOfWeek'}>,
#         <AxesSubplot:title={'center':'Sales'}>,
#         <AxesSubplot:title={'center':'Customers'}>],
#        [<AxesSubplot:title={'center':'Open'}>,
#         <AxesSubplot:title={'center':'Promo'}>,
#         <AxesSubplot:title={'center':'SchoolHoliday'}>,
#         <AxesSubplot:title={'center':'CompetitionDistance'}>],
#        [<AxesSubplot:title={'center':'CompetitionOpenSinceMonth'}>,
#         <AxesSubplot:title={'center':'CompetitionOpenSinceYear'}>,
#         <AxesSubplot:title={'center':'Promo2'}>,
#         <AxesSubplot:title={'center':'Promo2SinceWeek'}>],
#        [<AxesSubplot:title={'center':'Promo2SinceYear'}>,
#         <AxesSubplot:title={'center':'Month'}>,
#         <AxesSubplot:title={'center':'Quarter'}>,
#         <AxesSubplot:title={'center':'Year'}>],
#        [<AxesSubplot:title={'center':'Day'}>,
#         <AxesSubplot:title={'center':'Week'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_new.isnull().sum()/df_new.shape[0]*100
# Out:
# Store                         0.000000
# DayOfWeek                     0.000000
# Date                          0.000000
# Sales                         0.000000
# Customers                     0.000000
# Open                          0.000000
# Promo                         0.000000
# StateHoliday                  0.000000
# SchoolHoliday                 0.000000
# StoreType                     0.000000
# Assortment                    0.000000
# CompetitionDistance           0.259730
# CompetitionOpenSinceMonth    31.787764
# CompetitionOpenSinceYear     31.787764
# Promo2                        0.000000
# Promo2SinceWeek              49.943620
# Promo2SinceYear              49.943620
# PromoInterval                49.943620
# Month                         0.000000
# Quarter                       0.000000
# Year                          0.000000
# Day                           0.000000
# Week                          0.000000
# Season                        0.000000
# dtype: float64

# %%
#Replace nulls with the mode
df_new['CompetitionDistance']= df_new['CompetitionDistance'].fillna(df_new['CompetitionDistance'].mode()[0])
#Double check if we still see nulls for the column
df_new["CompetitionDistance"].isnull().sum()/df_new.shape[0]*100
# Out:
# 0.0

# %%
import seaborn as sns #Seaborn is another powerful visualization library for Python
sns.set(style='whitegrid')

#create the bar plot for Average Sales across different Seasons
ax = sns.barplot(x='Season',y='Sales',data=df_new)

# %%
#create the bar plot for Average Sales across different Assortments
ax = sns.barplot(x='Assortment',y='Sales',data=df_new)

# %%
#create the bar plot for Average Sales across different Store Types
ax = sns.barplot(x='StoreType',y='Sales',data=df_new)

# %%
ax = sns.barplot(x='Season',y='Sales',data=df_new,estimator=np.size)

# %%
ax = sns.barplot(x='Assortment',y='Sales',data=df_new,estimator=np.size)

# %%
ax = sns.barplot(x='StoreType',y='Sales',data=df_new,estimator=np.size)

# %%
#Define a variable for each type of feature
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
target = ["Sales"]
numeric_columns = ["Customers","Open","Promo","Promo2","StateHoliday","SchoolHoliday","CompetitionDistance"]
categorical_columns = ["DayOfWeek","Quarter","Month","Year","StoreType","Assortment","Season"]

#Define a function that will intake the raw dataframe and the column name and return a one hot encoded DF
def create_ohe(df,col):
    le = LabelEncoder()
    a = le.fit_transform(df_new[col]).reshape(-1,1)
    ohe = OneHotEncoder(sparse=False)
    column_names = [col+'_'+str(i) for i in le.classes_]
    return(pd.DataFrame(ohe.fit_transform(a),columns = column_names))
#Since the above function converts the column, one at a time
#We create a loop to create the final dataset with all features
temp = df_new[numeric_columns]
for column in categorical_columns:
    temp_df = create_ohe(df_new,column)
    temp=pd.concat([temp,temp_df],axis=1)

# %%
print("Shape of Data:",temp.shape)
print("Distinct Datatypes:",temp.dtypes.unique())
# Out:
# Shape of Data: (1017209, 44)
# Distinct Datatypes: [dtype('int64') dtype('O') dtype('float64')]

# %%
print(temp.columns[temp.dtypes=='object'])
# Out:
# Index(['StateHoliday'], dtype='object')

# %%
temp['StateHoliday'].unique()
# Out:
# array(['0', 'a', 'b', 'c', 0], dtype=object)

# %%
temp['StateHoliday']=np.where(temp['StateHoliday']=='0',0,1)
temp.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('int32'), dtype('float64')], dtype=object)

# %%
from sklearn.model_selection import train_test_split
#Create train and test dataset with an 80:20 split
x_train, x_test, y_train, y_test = train_test_split(temp,df_new[target],test_size=0.2,random_state=2018)
#Further divide training dataset into train and validation dataset with an 90:10 split
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train,test_size=0.1,random_state=2018)

#Check the sizes of all newly created datasets
print("Shape of x_train:",x_train.shape)
print("Shape of x_val:",x_val.shape)
print("Shape of x_test:",x_test.shape)
print("Shape of y_train:",y_train.shape)
print("Shape of y_val:",y_val.shape)
print("Shape of y_test:",y_test.shape)
# Out:
# Shape of x_train: (732390, 44)
# Shape of x_val: (81377, 44)
# Shape of x_test: (203442, 44)
# Shape of y_train: (732390, 1)
# Shape of y_val: (81377, 1)
# Shape of y_test: (203442, 1)

# %%
#calculate the average score of the train dataset
mean_sales = y_train.mean()
print('Average Sales :',mean_sales)
# Out:
# Average Sales : Sales    5773.099997
# dtype: float64

# %%
print('MAE for Test Data:',abs(y_test - mean_sales).mean()[0])
# Out:
# MAE for Test Data: 2883.587604303215

# %%
#Create Deep Neural Network Architecture
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(150,input_dim=44,activation='relu'))
#The input_dim=44,since the widtin of the training data = 44(refer data engg section)
model.add(Dense(1,activation='linear'))

#Configure the model
model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mean_absolute_error'])

#Train the model
model.fit(x_train.values,y_train.values,validation_data=(x_val,y_val),epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 11444/11444 [==============================] - 7s 575us/step - loss: 1202.1739 - mean_absolute_error: 1202.1739 - val_loss: 820.5206 - val_mean_absolute_error: 820.5206
# Epoch 2/10
# 11444/11444 [==============================] - 6s 558us/step - loss: 797.1683 - mean_absolute_error: 797.1683 - val_loss: 741.0334 - val_mean_absolute_error: 741.0334
# Epoch 3/10
# 11444/11444 [==============================] - 6s 560us/step - loss: 737.8372 - mean_absolute_error: 737.8372 - val_loss: 715.3900 - val_mean_absolute_error: 715.3900
# Epoch 4/10
# 11444/11444 [==============================] - 6s 567us/step - loss: 721.9668 - mean_absolute_error: 721.9668 - val_loss: 718.6010 - val_mean_absolute_error: 718.6010
# Epoch 5/10
# 11444/11444 [==============================] - 6s 563us/step - loss: 710.4649 - mean_absolute_error: 710.4649 - val_loss: 740.3041 - val_mean_absolute_error: 740.3041
# Epoch 6/10
# 11444/11444 [==============================] - 6s 566us/step - loss: 699.4886 - mean_absolute_error: 699.4886 - val_loss: 690.2157 - val_mean_absolute_error: 690.2157
# Epoch 7/10
# 11444/11444 [==============================] - 6s 566us/step - loss: 697.1306 - mean_absolute_error: 697.1306 - val_loss: 693.2889 - val_mean_absolute_error: 693.2889
# Epoch 8/10
# 11444/11444 [==============================] - 6s 564us/step - loss: 692.5148 - mean_absolute_error: 692.5148 - val_loss: 686.6795 - val_mean_absolute_error: 686.6795
# Epoch 9/10
# 11444/11444 [==============================] - 6s 551us/step - loss: 688.9329 - mean_absolute_error: 688.9329 - val_loss: 686.5106 - val_mean_absolute_error: 686.5106
# Epoch 10/10
# 11444/11444 [==============================] - 6s 553us/step - loss: 682.2939 - mean_absolute_error: 682.2939 - val_loss: 693.9721 - val_mean_absolute_error: 693.9721

# %%
#Use the model's evaluate method to predict and evaluate the test datasets
result = model.evaluate(x_test.values,y_test.values)

#Print the results
for i in range(len(model.metrics_names)):
    print('Metric ',model.metrics_names[i],':',str(round(result[i],2)))
# Out:
# 6358/6358 [==============================] - 4s 593us/step - loss: 690.0407 - mean_absolute_error: 690.0407
# Metric  loss : 690.04
# Metric  mean_absolute_error : 690.04
# Building graph of deps:   0%|          | 0/311 [00:00<?, ?it/s]
# Examining get_terminal_size:   0%|          | 0/311 [00:00<?, ?it/s]
# Examining h5py:   0%|          | 1/311 [00:00<00:00, 1002.94it/s]
# Examining prompt_toolkit:   1%|          | 2/311 [00:01<02:47,  1.84it/s]
# Examining prompt_toolkit:   1%|          | 3/311 [00:01<01:51,  2.76it/s]
# Examining beautifulsoup4:   1%|          | 3/311 [00:01<01:51,  2.76it/s]
# Examining beautifulsoup4:   1%|▏         | 4/311 [00:01<01:27,  3.50it/s]
# Examining @/win-64::__win==0=0:   1%|▏         | 4/311 [00:01<01:27,  3.50it/s]
# Examining python-libarchive-c:   2%|▏         | 5/311 [00:01<01:27,  3.50it/s]
# Examining markupsafe:   2%|▏         | 6/311 [00:01<01:27,  3.50it/s]
# Examining markupsafe:   2%|▏         | 7/311 [00:01<01:08,  4.45it/s]
# Examining pexpect:   2%|▏         | 7/311 [00:01<01:08,  4.45it/s]
# Examining openssl:   3%|▎         | 8/311 [00:01<01:08,  4.45it/s]
# Examining bokeh:   3%|▎         | 9/311 [00:01<01:07,  4.45it/s]
# Examining mccabe:   3%|▎         | 10/311 [00:05<01:07,  4.45it/s]
# Examining mccabe:   4%|▎         | 11/311 [00:05<02:15,  2.21it/s]
# Examining qdarkstyle:   4%|▎         | 11/311 [00:05<02:15,  2.21it/s]
# Examining zipp:   4%|▍         | 12/311 [00:05<02:15,  2.21it/s]
# Examining anaconda==2020.11:   4%|▍         | 13/311 [00:05<02:14,  2.21it/s]
# Examining json5:   5%|▍         | 14/311 [00:05<02:14,  2.21it/s]
# Examining json5:   5%|▍         | 15/311 [00:05<01:36,  3.06it/s]
# Examining pandoc:   5%|▍         | 15/311 [00:05<01:36,  3.06it/s]
# Examining pep8:   5%|▌         | 16/311 [00:05<01:36,  3.06it/s]
# Examining packaging:   5%|▌         | 17/311 [00:05<01:36,  3.06it/s]
# Examining importlib-metadata:  90%|████████▉ | 279/311 [01:17<00:08,  3.93it/s]
# Examining libxml2:  90%|█████████ | 280/311 [01:17<00:07,  3.93it/s]
# Examining libxml2:  90%|█████████ | 281/311 [01:17<00:05,  5.37it/s]
# Examining certifi:  90%|█████████ | 281/311 [01:17<00:05,  5.37it/s]
# Examining libsodium:  91%|█████████ | 282/311 [01:17<00:05,  5.37it/s]
# Examining libsodium:  91%|█████████ | 283/311 [01:17<00:04,  6.87it/s]
# Examining curl:  91%|█████████ | 283/311 [01:17<00:04,  6.87it/s]
# Examining yaml:  91%|█████████▏| 284/311 [01:17<00:03,  6.87it/s]
# Examining dask:  92%|█████████▏| 285/311 [01:17<00:03,  6.87it/s]
# Examining backports:  92%|█████████▏| 286/311 [01:27<00:03,  6.87it/s]
# Examining backports:  92%|█████████▏| 287/311 [01:27<00:21,  1.14it/s]
# Examining python-dateutil:  92%|█████████▏| 287/311 [01:27<00:21,  1.14it/s]
# Examining py-lief:  93%|█████████▎| 288/311 [01:27<00:20,  1.14it/s]
# Examining unicodecsv:  93%|█████████▎| 289/311 [01:27<00:19,  1.14it/s]
# Examining defusedxml:  93%|█████████▎| 290/311 [01:27<00:18,  1.14it/s]
# Examining pluggy:  94%|█████████▎| 291/311 [01:27<00:17,  1.14it/s]
# Examining pluggy:  94%|█████████▍| 292/311 [01:27<00:11,  1.61it/s]
# Examining notebook:  94%|█████████▍| 292/311 [01:27<00:11,  1.61it/s]
# Examining jupyterlab_pygments:  94%|█████████▍| 293/311 [01:30<00:11,  1.61it/s]
# Examining jupyterlab_pygments:  95%|█████████▍| 294/311 [01:30<00:15,  1.13it/s]
# Examining zope:  95%|█████████▍| 294/311 [01:30<00:15,  1.13it/s]
# Examining pycurl:  95%|█████████▍| 295/311 [01:30<00:14,  1.13it/s]
# Examining path:  95%|█████████▌| 296/311 [01:30<00:13,  1.13it/s]
# Examining gevent:  95%|█████████▌| 297/311 [01:30<00:12,  1.13it/s]
# Examining gevent:  96%|█████████▌| 298/311 [01:30<00:08,  1.59it/s]
# Examining llvmlite:  96%|█████████▌| 298/311 [01:31<00:08,  1.59it/s]
# Examining numpy:  96%|█████████▌| 299/311 [01:31<00:07,  1.59it/s]
# Examining numpy:  96%|█████████▋| 300/311 [01:31<00:06,  1.80it/s]
# Examining jupyterlab_server:  96%|█████████▋| 300/311 [01:32<00:06,  1.80it/s]
# Examining vs2015_runtime:  97%|█████████▋| 301/311 [01:33<00:05,  1.80it/s]
# Examining vs2015_runtime:  97%|█████████▋| 302/311 [01:33<00:05,  1.54it/s]
# Examining matplotlib:  97%|█████████▋| 302/311 [01:33<00:05,  1.54it/s]
# Examining jupyter_core:  97%|█████████▋| 303/311 [01:35<00:05,  1.54it/s]
# Examining jupyter_core:  98%|█████████▊| 304/311 [01:35<00:05,  1.37it/s]
# Examining sphinxcontrib-serializinghtml:  98%|█████████▊| 304/311 [01:35<00:05,  1.37it/s]
# Examining mkl_fft:  98%|█████████▊| 305/311 [01:35<00:04,  1.37it/s]
# Examining cffi:  98%|█████████▊| 306/311 [01:36<00:03,  1.37it/s]
# Examining cffi:  99%|█████████▊| 307/311 [01:36<00:02,  1.57it/s]
# Examining wincertstore:  99%|█████████▊| 307/311 [01:36<00:02,  1.57it/s]
# Examining pip:  99%|█████████▉| 308/311 [01:36<00:01,  1.57it/s]
# Examining iniconfig:  99%|█████████▉| 309/311 [01:37<00:01,  1.57it/s]
# Examining iniconfig: 100%|█████████▉| 310/311 [01:37<00:00,  1.78it/s]
# Examining distributed: 100%|█████████▉| 310/311 [01:37<00:00,  1.78it/s]
#
#
# Determining conflicts:   0%|          | 0/311 [00:00<?, ?it/s]
# Examining conflict for get_terminal_size anaconda:   0%|          | 0/311 [00:00<?, ?it/s]
# Examining conflict for get_terminal_size ipywidgets h5py prompt_toolkit anaconda-project pycparser astroid python-language-server snowballstemmer nltk typing_extensions beautifulsoup4 powershell_shortcut requests pkginfo python-libarchive-c win_inet_pton markupsafe pexpect cytoolz pynacl qtpy ply sip jupyter bokeh rope diff-match-patch mccabe imagesize prompt-toolkit idna qdarkstyle zipp qtconsole anaconda sphinxcontrib-qthelp mistune chardet json5 openpyxl sphinxcontrib-applehelp pywin32 jupyterlab numba send2trash testpath networkx bkcharts pytest conda-build simplegeneric pep8 pytz packaging py nbconvert bottleneck greenlet sortedcontainers paramiko six sympy fsspec _ipyw_jlab_nb_ext_conf cryptography pygments future atomicwrites keyring html5lib pyreadline werkzeug boto click lazy-object-proxy pyyaml setuptools bcrypt olefile nbclient conda-verify pandas pydocstyle cython importlib_metadata pywavelets threadpoolctl ipykernel widgetsnbextension pycodestyle jdcal console_shortcut scikit-learn conda bitarray locket nbformat comtypes dask-core pathlib2 backports.weakref itsdangerous anaconda-navigator spyder-kernels mpmath pysocks more-itertools cloudpickle glob2 jedi tornado alabaster regex pyrsistent backports.tempfile imageio partd argon2-cffi nose backcall autopep8 matplotlib-base prometheus_client tensorflow wheel spyder win_unicode_console pathtools docutils sphinxcontrib-htmlhelp seaborn traitlets statsmodels tifffile flake8 xlrd rtree yapf sphinxcontrib-devhelp psutil jsonschema zope.event multipledispatch kiwisolver clyent fastcache sphinxcontrib-websupport ipython intervaltree toolz brotlipy jupyter_client mock python-jsonrpc-server patsy entrypoints navigator-updater pyzmq jinja2 sphinxcontrib-jsmath pickleshare numpy-base tblib importlib-metadata asn1crypto joblib certifi sortedcollections backports.functools_lru_cache pywin32-ctypes dask sphinxcontrib conda-package-handling sphinx wcwidth qtawesome zope.interface cycler numpydoc xlwt backports python-dateutil xmltodict zict pyflakes pillow py-lief backports.shutil_get_terminal_size python menuinst pywinpty babel path.py unicodecsv toml soupsieve nest-asyncio astropy bleach msgpack-python ruamel_yaml anaconda-client wrapt decorator parso pyodbc singledispatch pyqt webencodings defusedxml ujson pluggy notebook jupyterlab_pygments attrs zope heapdict scikit-image pycurl path tqdm gevent contextlib2 urllib3 ipython_genutils async_generator llvmlite numpy sqlalchemy flask terminado jupyterlab_server et_xmlfile numexpr matplotlib lxml pycosat jupyter_console mkl-service jupyter_core sphinxcontrib-serializinghtml pyparsing mkl_fft pylint cffi filelock wincertstore pandocfilters argh mkl_random pip isort pyopenssl colorama scipy xlwings xlsxwriter pytables watchdog iniconfig distributed:   0%|          | 1/311 [00:00<00:02, 143.24it/s]
# Examining conflict for get_terminal_size flake8 backports.shutil_get_terminal_size astroid python-language-server pywinpty path.py soupsieve ipython conda-verify pydocstyle importlib_metadata anaconda entrypoints backports.weakref matplotlib tornado backports.functools_lru_cache pylint backports.tempfile isort backports:   1%|          | 2/311 [00:14<37:13,  7.23s/it]
# Examining conflict for get_terminal_size flake8 backports.shutil_get_terminal_size astroid python-language-server pywinpty path.py soupsieve ipython conda-verify pydocstyle importlib_metadata anaconda entrypoints backports.weakref matplotlib tornado backports.functools_lru_cache pylint backports.tempfile isort backports:   1%|          | 3/311 [00:14<24:44,  4.82s/it]
# Examining conflict for ipython get_terminal_size ipywidgets jupyterlab backports.shutil_get_terminal_size ipykernel jupyter_console anaconda:   1%|          | 3/311 [00:17<24:44,  4.82s/it]
# Examining conflict for ipython get_terminal_size ipywidgets jupyterlab backports.shutil_get_terminal_size ipykernel jupyter_console anaconda:   1%|▏         | 4/311 [00:17<22:04,  4.31s/it]
# Examining conflict for tensorflow anaconda h5py:   1%|▏         | 4/311 [00:20<22:04,  4.31s/it]
# Examining conflict for tensorflow anaconda h5py:   2%|▏         | 5/311 [00:20<19:44,  3.87s/it]
# Examining conflict for ipywidgets bzip2 h5py prompt_toolkit anaconda-project pycparser astroid python-language-server snowballstemmer nltk typing_extensions beautifulsoup4 powershell_shortcut requests pkginfo python-libarchive-c win_inet_pton markupsafe pexpect cytoolz openssl pynacl qtpy ply freetype sip jupyter bokeh rope diff-match-patch mccabe imagesize prompt-toolkit idna qdarkstyle zipp qtconsole anaconda sphinxcontrib-qthelp mistune chardet json5 openpyxl sphinxcontrib-applehelp pywin32 jupyterlab numba send2trash testpath blosc networkx bkcharts pytest conda-build simplegeneric pep8 pytz packaging py nbconvert bottleneck greenlet winpty sortedcontainers paramiko six sympy fsspec xz zstd libspatialindex _ipyw_jlab_nb_ext_conf cryptography pygments future atomicwrites keyring html5lib pyreadline werkzeug boto click lazy-object-proxy pyyaml setuptools bcrypt libssh2 olefile nbclient conda-verify hdf5 pandas pydocstyle cython zeromq importlib_metadata pywavelets threadpoolctl ipykernel widgetsnbextension pycodestyle jdcal console_shortcut scikit-learn conda bitarray locket nbformat comtypes dask-core pathlib2 backports.weakref itsdangerous anaconda-navigator spyder-kernels mpmath pysocks more-itertools cloudpickle glob2 jedi tornado alabaster regex pyrsistent backports.tempfile imageio partd libtiff argon2-cffi libarchive qt autopep8 nose matplotlib-base prometheus_client tensorflow backcall wheel spyder win_unicode_console pathtools docutils sphinxcontrib-htmlhelp seaborn traitlets statsmodels tifffile flake8 xlrd rtree yapf sphinxcontrib-devhelp psutil jsonschema zope.event multipledispatch kiwisolver clyent fastcache defusedxml sphinxcontrib-websupport ipython liblief intervaltree toolz brotlipy icu jupyter_client mock python-jsonrpc-server patsy entrypoints navigator-updater pyzmq jinja2 sphinxcontrib-jsmath pickleshare numpy-base tblib importlib-metadata libxml2 asn1crypto joblib certifi lzo sortedcollections libsodium curl backports.functools_lru_cache yaml pywin32-ctypes dask sphinxcontrib conda-package-handling sphinx wcwidth qtawesome zope.interface cycler numpydoc xlwt backports python-dateutil xmltodict zict pyflakes pillow py-lief libcurl backports.shutil_get_terminal_size python menuinst pywinpty babel path.py unicodecsv toml soupsieve nest-asyncio astropy bleach msgpack-python ruamel_yaml anaconda-client wrapt decorator parso pyodbc sqlite singledispatch webencodings pyqt ujson pluggy notebook vc attrs jupyterlab_pygments heapdict scikit-image zope pycurl tqdm path gevent contextlib2 urllib3 ipython_genutils async_generator llvmlite numpy sqlalchemy jpeg flask krb5 terminado jupyterlab_server et_xmlfile numexpr vs2015_runtime lxml zlib libiconv pycosat jupyter_console libxslt mkl-service matplotlib jupyter_core sphinxcontrib-serializinghtml pyparsing libpng pylint mkl_fft cffi filelock wincertstore pandocfilters argh mkl_random pip isort pyopenssl colorama scipy lz4-c xlwings xlsxwriter pytables watchdog tk iniconfig distributed:   2%|▏         | 5/311 [00:23<19:44,  3.87s/it]
# Examining conflict for ipywidgets bzip2 h5py prompt_toolkit anaconda-project pycparser astroid python-language-server snowballstemmer nltk typing_extensions beautifulsoup4 powershell_shortcut requests pkginfo python-libarchive-c win_inet_pton markupsafe pexpect cytoolz openssl pynacl qtpy ply freetype sip jupyter bokeh rope diff-match-patch mccabe imagesize prompt-toolkit idna qdarkstyle zipp qtconsole anaconda sphinxcontrib-qthelp mistune chardet json5 openpyxl sphinxcontrib-applehelp pywin32 jupyterlab numba send2trash testpath blosc networkx bkcharts pytest conda-build simplegeneric pep8 pytz packaging py nbconvert bottleneck greenlet winpty sortedcontainers paramiko six sympy fsspec xz zstd libspatialindex _ipyw_jlab_nb_ext_conf cryptography pygments future atomicwrites keyring html5lib pyreadline werkzeug boto click lazy-object-proxy pyyaml setuptools bcrypt libssh2 olefile nbclient conda-verify hdf5 pandas pydocstyle cython zeromq importlib_metadata pywavelets threadpoolctl ipykernel widgetsnbextension pycodestyle jdcal console_shortcut scikit-learn conda bitarray locket nbformat comtypes dask-core pathlib2 backports.weakref itsdangerous anaconda-navigator spyder-kernels mpmath pysocks more-itertools cloudpickle glob2 jedi tornado alabaster regex pyrsistent backports.tempfile imageio partd libtiff argon2-cffi libarchive qt autopep8 nose matplotlib-base prometheus_client tensorflow backcall wheel spyder win_unicode_console pathtools docutils sphinxcontrib-htmlhelp seaborn traitlets statsmodels tifffile flake8 xlrd rtree yapf sphinxcontrib-devhelp psutil jsonschema zope.event multipledispatch kiwisolver clyent fastcache defusedxml sphinxcontrib-websupport ipython liblief intervaltree toolz brotlipy icu jupyter_client mock python-jsonrpc-server patsy entrypoints navigator-updater pyzmq jinja2 sphinxcontrib-jsmath pickleshare numpy-base tblib importlib-metadata libxml2 asn1crypto joblib certifi lzo sortedcollections libsodium curl backports.functools_lru_cache yaml pywin32-ctypes dask sphinxcontrib conda-package-handling sphinx wcwidth qtawesome zope.interface cycler numpydoc xlwt backports python-dateutil xmltodict zict pyflakes pillow py-lief libcurl backports.shutil_get_terminal_size python menuinst pywinpty babel path.py unicodecsv toml soupsieve nest-asyncio astropy bleach msgpack-python ruamel_yaml anaconda-client wrapt decorator parso pyodbc sqlite singledispatch webencodings pyqt ujson pluggy notebook vc attrs jupyterlab_pygments heapdict scikit-image zope pycurl tqdm path gevent contextlib2 urllib3 ipython_genutils async_generator llvmlite numpy sqlalchemy jpeg flask krb5 terminado jupyterlab_server et_xmlfile numexpr vs2015_runtime lxml zlib libiconv pycosat jupyter_console libxslt mkl-service matplotlib jupyter_core sphinxcontrib-serializinghtml pyparsing libpng pylint mkl_fft cffi filelock wincertstore pandocfilters argh mkl_random pip isort pyopenssl colorama scipy lz4-c xlwings xlsxwriter pytables watchdog tk iniconfig distributed:   2%|▏         | 6/311 [00:23<18:53,  3.72s/it]
# Examining conflict for statsmodels tifffile h5py nltk astropy bokeh pandas scikit-image pywavelets anaconda patsy scikit-learn numpy numpy-base numba bkcharts numexpr matplotlib mkl-service mkl_fft dask imageio bottleneck mkl_random matplotlib-base scipy pytables seaborn:   2%|▏         | 6/311 [00:37<18:53,  3.72s/it]
# ...
#
# Package pickleshare conflicts for:
# ipywidgets -> ipython[version='>=4.0.0'] -> pickleshare
# anaconda==2020.11 -> pickleshare==0.7.5[build='py38_1000|py37_1001']
# jupyter_console -> ipython -> pickleshare
# spyder-kernels -> ipython[version='>=7.6.0'] -> pickleshare
# anaconda==2020.11 -> ipython==7.19.0=py37hd4e2768_0 -> pickleshare[version='>=0.4']
# ipykernel -> ipython[version='>=5.0'] -> pickleshare
# jupyterlab -> ipython -> pickleshare
# ipython -> pickleshare
# spyder -> pickleshare[version='>=0.4']
#
# Package heapdict conflicts for:
# zict -> heapdict
# anaconda==2020.11 -> heapdict==1.0.1=py_0
# anaconda==2020.11 -> zict==2.0.0=py_0 -> heapdict
# distributed -> zict[version='>=0.1.3'] -> heapdict
#
# Package pympler conflicts for:
# attrs -> pympler
# pytest -> attrs[version='>=17.2.0'] -> pympler
# spyder -> pympler
#
# Package wrapt conflicts for:
# astroid -> wrapt[version='1.11.*|>=1.11,<2']
# tensorflow -> tensorflow-base==2.3.0=eigen_py37h17acbac_0 -> wrapt[version='>=1.11.1|>=1.11|>=1.11.2,<2.0a0|>=1.11.2|>=1.12.1']
# anaconda==2020.11 -> wrapt==1.11.2[build='py37he774522_0|py38he774522_0']
# pylint -> astroid[version='>=2.4.0,<=2.5'] -> wrapt[version='1.11.*|>=1.11,<2']
# anaconda==2020.11 -> astroid==2.4.2=py37_0 -> wrapt=1.11
#
# Package jupyterlab_widgets conflicts for:
# _ipyw_jlab_nb_ext_conf -> ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
# ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
# jupyter -> ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
#
# Package backports.shutil_which conflicts for:
# pywinpty -> backports.shutil_which
# terminado -> pywinpty -> backports.shutil_which
#
# Package statsmodels conflicts for:
# seaborn -> statsmodels[version='>=0.5.0']
# anaconda==2020.11 -> statsmodels==0.12.0[build='py37he774522_0|py38he774522_0']
#
# Package libxslt conflicts for:
# lxml -> libxslt[version='>=1.1.32,<2.0a0|>=1.1.33,<2.0a0|>=1.1.34,<2.0a0']
# anaconda==2020.11 -> libxslt==1.1.34=he774522_0
# anaconda==2020.11 -> lxml==4.6.1=py37h1350720_0 -> libxslt[version='>=1.1.34,<2.0a0']
#
# Package zope.event conflicts for:
# gevent -> zope.event
# anaconda==2020.11 -> zope.event==4.5.0[build='py38_0|py37_0']
# anaconda==2020.11 -> gevent==20.9.0=py37he774522_0 -> zope.event
#
# Package babel conflicts for:
# numpydoc -> sphinx -> babel[version='>=1.3|>=1.3,!=2.0']
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> babel
# spyder -> sphinx[version='>=0.6.6'] -> babel[version='>=1.3|>=1.3,!=2.0']
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> babel[version='>=1.3,!=2.0']
# sphinx -> babel[version='>=1.3|>=1.3,!=2.0']
# anaconda==2020.11 -> babel==2.8.1=pyhd3eb1b0_0
# jupyterlab_server -> babel
#
# Package sphinxcontrib-devhelp conflicts for:
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> sphinxcontrib-devhelp
# anaconda==2020.11 -> sphinxcontrib-devhelp==1.0.2=py_0
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-devhelp
# sphinx -> sphinxcontrib-devhelp
# numpydoc -> sphinx -> sphinxcontrib-devhelp
#
# Package scikit-learn conflicts for:
# anaconda==2020.11 -> scikit-learn==0.23.2[build='py37h47e9c7a_0|py38h47e9c7a_0']
# nltk -> scikit-learn
#
# Package zict conflicts for:
# anaconda==2020.11 -> distributed==2.30.1=py37haa95532_0 -> zict[version='>=0.1.3']
# distributed -> zict[version='>=0.1.2|>=0.1.3']
# dask -> distributed[version='>=2021.4.0'] -> zict[version='>=0.1.2|>=0.1.3']
# anaconda==2020.11 -> zict==2.0.0=py_0
#
# Package menuinst conflicts for:
# anaconda==2020.11 -> menuinst==1.4.16[build='py38he774522_1|py37he774522_1']
# conda[version='>=4.9.2'] -> menuinst[version='>=1.4.11,<2']
# conda-build -> conda[version='>=4.5'] -> menuinst[version='>=1.4.11,<2']
#
# Package threadpoolctl conflicts for:
# nltk -> scikit-learn -> threadpoolctl
# anaconda==2020.11 -> threadpoolctl==2.1.0=pyh5ca1d4c_0
# scikit-learn -> threadpoolctl
# anaconda==2020.11 -> scikit-learn==0.23.2=py37h47e9c7a_0 -> threadpoolctl
#
# Package soupsieve conflicts for:
# anaconda==2020.11 -> beautifulsoup4==4.9.3=pyhb0f4dca_0 -> soupsieve[version='>=1.2']
# conda-build -> beautifulsoup4 -> soupsieve[version='>=1.2']
# anaconda==2020.11 -> soupsieve==2.0.1=py_0
# beautifulsoup4 -> soupsieve[version='>=1.2']
#
# Package cryptography-vectors conflicts for:
# urllib3 -> cryptography[version='>=1.3.4'] -> cryptography-vectors=2.3
# pyopenssl -> cryptography[version='>=2.2.1'] -> cryptography-vectors=2.3
# cryptography -> cryptography-vectors=2.3
# paramiko -> cryptography[version='>=1.5'] -> cryptography-vectors=2.3
#
# Package py conflicts for:
# anaconda==2020.11 -> pytest==6.1.1=py37_0 -> py[version='>=1.8.2']
# anaconda==2020.11 -> py==1.9.0=py_0
# pytest -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
# astropy -> pytest[version='<4'] -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
#
# Package rope conflicts for:
# anaconda==2020.11 -> python-language-server==0.35.1=py_0 -> rope[version='>=0.10.5']
# python-language-server -> rope[version='>=0.10.5']
# spyder -> rope[version='>=0.10.5|>=0.9.4']
# anaconda==2020.11 -> rope==0.18.0=py_0
#
# Package bkcharts conflicts for:
# anaconda==2020.11 -> bkcharts==0.2[build='py38_0|py37_0']
# bokeh -> bkcharts[version='>=0.2']
# dask -> bokeh -> bkcharts[version='>=0.2']
#
# Package pytest conflicts for:
# anaconda==2020.11 -> pytest==6.1.1[build='py38_0|py37_0']
# astropy -> pytest[version='<3.7|<4']
# astropy -> pytest-astropy -> pytest[version='>=3.1|>=3.1.0']
#
# Package imagesize conflicts for:
# sphinx -> imagesize
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> imagesize
# numpydoc -> sphinx -> imagesize
# anaconda==2020.11 -> imagesize==1.2.0=py_0
# spyder -> sphinx[version='>=0.6.6'] -> imagesize
#
# Package sortedcontainers conflicts for:
# sortedcollections -> sortedcontainers[version='>=2.0']
# attrs -> hypothesis -> sortedcontainers[version='>=2.1.0,<3.0.0']
# dask -> distributed[version='>=2021.4.0'] -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# intervaltree -> sortedcontainers
# anaconda==2020.11 -> distributed==2.30.1=py37haa95532_0 -> sortedcontainers[version='!=2.0.0,!=2.0.1|>=2.0']
# spyder -> intervaltree[version='>=3.0.2'] -> sortedcontainers
# anaconda==2020.11 -> sortedcontainers==2.2.2=py_0
# distributed -> sortedcontainers[version='!=2.0.0,!=2.0.1']
#
# Package dask conflicts for:
# scikit-image -> dask[version='>=0.5']
# anaconda==2020.11 -> dask==2.30.0=py_0
#
# Package pyasn1 conflicts for:
# paramiko -> pyasn1[version='>=0.1.7']
# spyder -> paramiko[version='>=2.4.0'] -> pyasn1[version='>=0.1.7']
# prometheus_client -> twisted -> pyasn1
#
# Package alabaster conflicts for:
# numpydoc -> sphinx -> alabaster[version='>=0.7,<0.8']
# spyder -> sphinx[version='>=0.6.6'] -> alabaster[version='>=0.7,<0.8']
# sphinx -> alabaster[version='>=0.7,<0.8']
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> alabaster[version='>=0.7,<0.8']
# anaconda==2020.11 -> alabaster==0.7.12[build='py37_0|py_0']
#
# Package pyreadline conflicts for:
# h5py -> pyreadline
# anaconda==2020.11 -> h5py==2.10.0=py37h5e291fa_0 -> pyreadline
# anaconda==2020.11 -> pyreadline==2.1[build='py38_1|py37_1']
#
# Package glob2 conflicts for:
# conda-build -> glob2[version='>=0.6']
# anaconda==2020.11 -> glob2==0.7=py_0
#
# Package et_xmlfile conflicts for:
# openpyxl -> et_xmlfile
# anaconda==2020.11 -> openpyxl==3.0.5=py_0 -> et_xmlfile
# anaconda==2020.11 -> et_xmlfile==1.0.1=py_1001
#
# Package pycodestyle conflicts for:
# anaconda==2020.11 -> autopep8==1.5.4=py_0 -> pycodestyle[version='>=2.6|>=2.6.0,<2.7.0']
# autopep8 -> pycodestyle[version='>=2.3|>=2.6']
# python-language-server -> autopep8 -> pycodestyle[version='>=2.0.0,<2.4.0|>=2.0.0,<2.5.0|>=2.3|>=2.6|>=2.5.0,<2.6.0|>=2.4.0,<2.5.0']
# flake8 -> pycodestyle[version='>=2.0.0,<2.4.0|>=2.0.0,<2.5.0|>=2.4.0,<2.5.0|>=2.5.0,<2.6.0|>=2.6.0,<2.7.0']
# anaconda==2020.11 -> pycodestyle==2.6.0=py_0
# python-language-server -> pycodestyle[version='>=2.6.0,<2.7.0']
# spyder -> pycodestyle
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> pycodestyle[version='>=2.6.0,<2.7.0']
#
# Package krb5 conflicts for:
# anaconda==2020.11 -> krb5==1.18.2=hc04afaa_0
# anaconda==2020.11 -> curl==7.71.1=h2a8f88b_1 -> krb5[version='>=1.18.2,<1.19.0a0']
# curl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# pycurl -> libcurl[version='>=7.71.1,<8.0a0'] -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# libcurl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
#
# Package sphinxcontrib conflicts for:
# sphinx -> sphinxcontrib-websupport -> sphinxcontrib
# sphinxcontrib-websupport -> sphinxcontrib
# anaconda==2020.11 -> sphinxcontrib-websupport==1.2.4=py_0 -> sphinxcontrib
# anaconda==2020.11 -> sphinxcontrib==1.0[build='py38_1|py37_1']
#
# Package mistune conflicts for:
# notebook -> nbconvert -> mistune[version='>0.6|>=0.8.1']
# spyder -> nbconvert[version='>=4.0'] -> mistune[version='>0.6|>=0.8.1']
# nbconvert -> mistune[version='>0.6|>=0.8.1']
# anaconda==2020.11 -> nbconvert==6.0.7=py37_0 -> mistune[version='>=0.8.1']
# jupyter -> nbconvert -> mistune[version='>0.6|>=0.8.1']
# anaconda==2020.11 -> mistune==0.8.4[build='py38he774522_1000|py37hfa6e2cd_1001']
#
# Package twisted conflicts for:
# notebook -> prometheus_client -> twisted
# prometheus_client -> twisted
#
# Package scandir conflicts for:
# pytest -> pathlib2[version='>=2.2.0'] -> scandir
# testpath -> pathlib2 -> scandir
# conda-build -> scandir
# pathlib2 -> scandir
# ipython -> pathlib2 -> scandir
# importlib_metadata -> pathlib2 -> scandir
# pickleshare -> pathlib2 -> scandir
#
# Package ssl_match_hostname conflicts for:
# ipykernel -> tornado[version='>=4.2'] -> ssl_match_hostname
# distributed -> tornado[version='>=4.5.1'] -> ssl_match_hostname
# bokeh -> tornado[version='>=4.3'] -> ssl_match_hostname
# matplotlib-base -> tornado -> ssl_match_hostname
# terminado -> tornado[version='>=4'] -> ssl_match_hostname
# matplotlib -> tornado -> ssl_match_hostname
# jupyterlab -> tornado[version='!=6.0.0,!=6.0.1,!=6.0.2'] -> ssl_match_hostname
# notebook -> tornado[version='>=4.1,<7'] -> ssl_match_hostname
# anaconda-project -> tornado[version='>=4.2'] -> ssl_match_hostname
# jupyter_client -> tornado[version='>=4.1'] -> ssl_match_hostname
# tornado -> ssl_match_hostname
#
# Package joblib conflicts for:
# anaconda==2020.11 -> joblib==0.17.0=py_0
# anaconda==2020.11 -> nltk==3.5=py_0 -> joblib[version='>=0.11']
# nltk -> scikit-learn -> joblib[version='>=0.11']
# scikit-learn -> joblib[version='>=0.11']
# nltk -> joblib
#
# Package jdcal conflicts for:
# openpyxl -> jdcal
# anaconda==2020.11 -> openpyxl==3.0.5=py_0 -> jdcal
# anaconda==2020.11 -> jdcal==1.4.1=py_0
#
# Package jupyter_server conflicts for:
# jupyterlab_server -> jupyter_server[version='>=1.1.0,<2.0.0']
# jupyterlab -> jupyter_server[version='>=1.4,<2']
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> jupyter_server[version='>=1.0.1,<2.0.0|>=1.1.0,<2.0.0']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyter_server[version='>=1.4,<2']
#
# Package atomicwrites conflicts for:
# anaconda==2020.11 -> atomicwrites==1.4.0=py_0
# astropy -> pytest[version='<4'] -> atomicwrites[version='>=1.0']
# spyder -> atomicwrites[version='>=1.2.0']
# pytest -> atomicwrites[version='>=1.0']
# anaconda==2020.11 -> pytest==6.1.1=py37_0 -> atomicwrites[version='>=1.0|>=1.2.0']
#
# Package patsy conflicts for:
# seaborn -> patsy
# anaconda==2020.11 -> patsy==0.5.1[build='py38_0|py37_0']
# statsmodels -> patsy[version='>=0.4.0|>=0.5.1']
# anaconda==2020.11 -> statsmodels==0.12.0=py37he774522_0 -> patsy[version='>=0.5.1']
# seaborn -> statsmodels[version='>=0.5.0'] -> patsy[version='>=0.4.0|>=0.5.1']
#
# Package backports.tempfile conflicts for:
# conda-verify -> backports.tempfile
# conda-build -> conda-verify -> backports.tempfile
#
# Package itsdangerous conflicts for:
# anaconda==2020.11 -> flask==1.1.2=py_0 -> itsdangerous[version='>=0.24']
# anaconda==2020.11 -> itsdangerous==1.1.0[build='py37_0|py_0']
# flask -> itsdangerous[version='>=0.21|>=0.24']
#
# Package dataclasses conflicts for:
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> dataclasses
# jupyterlab_server -> jupyter_server[version='>=1.1.0,<2.0.0'] -> dataclasses
#
# Package isort conflicts for:
# pylint -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# anaconda==2020.11 -> isort==5.6.4=py_0
# spyder -> pylint[version='>=1.0'] -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# python-language-server -> pylint[version='>=2.5.0'] -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# anaconda==2020.11 -> pylint==2.6.0=py37_0 -> isort[version='>=4.2.5,<6']
#
# Package libllvm9 conflicts for:
# numba -> llvmlite[version='>=0.33.0'] -> libllvm9
# llvmlite -> libllvm9
#
# Package tbb4py conflicts for:
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
# numpy-base -> tbb4py
# numpy -> numpy-base==1.15.4=py27h2753ae9_0 -> tbb4py
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
#
# Package ptyprocess conflicts for:
# spyder -> pexpect[version='>=4.4.0'] -> ptyprocess[version='>=0.5']
# pexpect -> ptyprocess[version='>=0.5']
#
# Package bcrypt conflicts for:
# anaconda==2020.11 -> bcrypt==3.2.0[build='py37he774522_0|py38he774522_0']
# paramiko -> bcrypt[version='>=3.1.3']
# anaconda==2020.11 -> paramiko==2.7.2=py_0 -> bcrypt[version='>=3.1.3']
# spyder -> paramiko[version='>=2.4.0'] -> bcrypt[version='>=3.1.3']
# prometheus_client -> twisted -> bcrypt
#
# Package h5py conflicts for:
# anaconda==2020.11 -> h5py==2.10.0[build='py37h5e291fa_0|py38h5e291fa_0']
# tensorflow -> tensorflow-base==2.3.0=eigen_py37h17acbac_0 -> h5py[version='>=2.10.0,<2.11.0a0']
#
# Package imagecodecs conflicts for:
# scikit-image -> tifffile[version='>=2019.7.26'] -> imagecodecs
# tifffile -> imagecodecs
#
# Package ipywidgets conflicts for:
# anaconda==2020.11 -> jupyter==1.0.0=py37_7 -> ipywidgets
# jupyter -> ipywidgets
# _ipyw_jlab_nb_ext_conf -> ipywidgets
# anaconda==2020.11 -> ipywidgets==7.5.1=py_1
#
# Package pyrsistent conflicts for:
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> pyrsistent[version='>=0.14.0']
# anaconda==2020.11 -> jsonschema==3.2.0=py_2 -> pyrsistent[version='>=0.14.0']
# spyder -> jsonschema[version='>=3.2.0'] -> pyrsistent[version='>=0.14.0']
# anaconda==2020.11 -> pyrsistent==0.17.3[build='py37he774522_0|py38he774522_0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> pyrsistent[version='>=0.14.0']
# jsonschema -> pyrsistent[version='>=0.14.0']
#
# Package python-jsonrpc-server conflicts for:
# python-language-server -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
# anaconda==2020.11 -> python-jsonrpc-server==0.4.0=py_0
# anaconda==2020.11 -> python-language-server==0.35.1=py_0 -> python-jsonrpc-server[version='>=0.4.0']
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
#
# Package black conflicts for:
# attrs -> hypothesis -> black[version='>=19.10b0']
# spyder -> pyls-black[version='>=0.4.6'] -> black
#
# Package curl conflicts for:
# anaconda==2020.11 -> curl==7.71.1=h2a8f88b_1
# pycurl -> curl[version='7.55.*|>=7.55.1,<8.0a0']
#
# Package jupyterlab_launcher conflicts for:
# jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
#
# Package pycosat conflicts for:
# conda[version='>=4.9.2'] -> pycosat[version='>=0.6.3']
# conda-build -> conda[version='>=4.5'] -> pycosat[version='>=0.6.1|>=0.6.3']
# anaconda==2020.11 -> pycosat==0.6.3[build='py37he774522_0|py38he774522_0']
#
# Package spyder-kernels conflicts for:
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.10.1,<1.11.0|>=1.10.2,<1.11.0|>=2.0.1,<2.1.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> spyder-kernels[version='>=1.9.4,<1.10.0']
# anaconda==2020.11 -> spyder-kernels==1.9.4[build='py38_0|py37_0']
#
# Package path conflicts for:
# anaconda==2020.11 -> path==15.0.0[build='py38_0|py37_0']
# anaconda==2020.11 -> path.py==12.5.0=0 -> path
# path.py -> path[version='<13.2']
#
# Package pkginfo conflicts for:
# anaconda==2020.11 -> pkginfo==1.6.1[build='py38haa95532_0|py37haa95532_0']
# conda-build -> pkginfo
#
# Package contextvars conflicts for:
# dask -> distributed[version='>=2021.3.0'] -> contextvars
# distributed -> contextvars
